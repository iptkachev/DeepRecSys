# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
from dataclasses import dataclass


@dataclass
class PipelineConfig:
    batch_size: int = 4
    d_model: int = 64
    n_heads: int = 4
    dropout: float = 0.1
    dim_feedforward: int = 256
    num_layers: int = 2
    num_epochs: int = 2
    gradient_clipping: float = 1.0
    logging_every_n_steps: int = 10
    validation_every_n_steps: int = 20
    tensorboard_every_n_steps: int = 10
    learning_rate: float = 1e-3


config = PipelineConfig()

# %% [markdown]
# # Yambda

# %%
import torch

from neuralrec.data.dataloader import DataLoader
from neuralrec.data.transforms import ToDevice
from neuralrec.ext.yambda.utils import load_yambda_user_split
from neuralrec.ext.yambda.transforms import pad_collate_item_id


train_dataset, valid_dataset, max_item_id = load_yambda_user_split()

train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=config.batch_size,
    shuffle=False,
    collate_fn=pad_collate_item_id,
    transforms=ToDevice(torch.device("cuda"))
)
valid_loader = DataLoader(
    dataset=valid_dataset,
    batch_size=config.batch_size,
    shuffle=False,
    collate_fn=pad_collate_item_id,
    transforms=ToDevice(torch.device("cuda")),
)

# %% [markdown]
# # Model

# %%
import torch
import torch.nn as nn

from neuralrec.nn.transformer import TransformerEncoder


class RecommenderTransformer(nn.Module):
    def __init__(
        self,
        num_items: int,
        d_model: int,
        encoder: nn.Module,
    ):
        super().__init__()
        self.num_items = num_items
        self.embedding = nn.Embedding(num_items + 1, d_model, padding_idx=0)
        self.encoder = encoder
        self.to_logits = nn.Linear(d_model, num_items + 1)

    def forward(self, batch) -> dict[str, torch.Tensor]:
        item_id = batch['item_id']
        x = self.embedding(item_id)
        h = self.encoder(x)
        logits = self.to_logits(h)

        logits_pred = logits[:, :-1].contiguous().view(-1, self.num_items + 1)
        target = item_id[:, 1:].contiguous().view(-1)

        loss = nn.functional.cross_entropy(
            logits_pred, target, ignore_index=0, reduction="mean"
        )
        return {"loss": loss}

# %% [markdown]
# # Train Loop

# %%
from neuralrec.run.train import TrainRunner
from neuralrec.run.callbacks import (
    GradientNormClippingCallback,
    LoggingCallback,
    ValidationCallback,
    TensorBoardCallback,
)

model = RecommenderTransformer(
    num_items=max_item_id,
    d_model=config.d_model,
    encoder=TransformerEncoder(
        d_model=config.d_model,
        nhead=config.n_heads,
        num_layers=config.num_layers,
        dim_feedforward=config.dim_feedforward,
        dropout=config.dropout,
        causal=True,
    )
).cuda()

optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate, fused=True)

TrainRunner(
    model=model,
    optimizer=optimizer,
    train_loader=train_loader,
    callbacks=[
        GradientNormClippingCallback(config.gradient_clipping),
        ValidationCallback(valid_loader).every_n_steps(config.validation_every_n_steps),
        LoggingCallback().every_n_steps(config.logging_every_n_steps),
        TensorBoardCallback().every_n_steps(config.tensorboard_every_n_steps),
    ],
).fit(num_epochs=config.num_epochs)
# Out:
# /home/matveevar/seminar/neuralrec/neuralrec/nn/transformer.py:33: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer_encoder = nn.TransformerEncoder(
# 2026-02-24 12:22:54.798 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=0 loss=13.8087
# 2026-02-24 12:22:56.873 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=0 loss=13.7970 validation/loss=13.793208732604981
# 2026-02-24 12:22:57.988 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=0 loss=13.6994
# 2026-02-24 12:23:00.053 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=0 loss=13.2379 validation/loss=13.267189216613769
# 2026-02-24 12:23:01.164 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=0 loss=12.5717
# 2026-02-24 12:23:03.238 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=0 loss=12.2290 validation/loss=12.633281211853028
# 2026-02-24 12:23:04.350 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=0 loss=12.7497
# 2026-02-24 12:23:06.450 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=0 loss=13.0581 validation/loss=12.440802345275879
# 2026-02-24 12:23:07.564 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=0 loss=12.9306
# 2026-02-24 12:23:09.654 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=0 loss=11.9821 validation/loss=12.26697654724121
# 2026-02-24 12:23:10.767 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=0 loss=12.2428
# 2026-02-24 12:23:12.823 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=0 loss=12.1606 validation/loss=12.176304130554199
# 2026-02-24 12:23:13.192 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 0 finished
# 2026-02-24 12:23:14.496 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=1 loss=8.8000
# 2026-02-24 12:23:16.577 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=1 loss=9.2485 validation/loss=12.763954048156739
# 2026-02-24 12:23:17.689 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=1 loss=9.4558
# 2026-02-24 12:23:19.765 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=1 loss=9.4317 validation/loss=12.883042106628418
# 2026-02-24 12:23:20.879 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=1 loss=9.5664
# 2026-02-24 12:23:22.935 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=1 loss=9.7524 validation/loss=12.5406396484375
# 2026-02-24 12:23:24.053 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=1 loss=10.3533
# 2026-02-24 12:23:26.116 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=1 loss=10.8079 validation/loss=12.595239753723144
# 2026-02-24 12:23:27.232 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=1 loss=10.8559
# 2026-02-24 12:23:29.335 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=1 loss=10.3349 validation/loss=12.442464027404785
# 2026-02-24 12:23:30.454 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=1 loss=10.5821
# 2026-02-24 12:23:32.517 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=1 loss=10.7099 validation/loss=12.279013175964355
# 2026-02-24 12:23:32.883 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 1 finished

# %% [markdown]
# # Mixed Precision

# %%
from neuralrec.nn.autocast import AutoCast

model = RecommenderTransformer(
    num_items=max_item_id,
    d_model=config.d_model,
    encoder=TransformerEncoder(
        d_model=config.d_model,
        nhead=config.n_heads,
        num_layers=config.num_layers,
        dim_feedforward=config.dim_feedforward,
        dropout=config.dropout,
        causal=True,
    )
).cuda()
model = AutoCast(model)  # if using fp16, use GradScaler

optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate, fused=True)

TrainRunner(
    model=model,
    optimizer=optimizer,
    train_loader=train_loader,
    callbacks=[
        GradientNormClippingCallback(config.gradient_clipping),
        ValidationCallback(valid_loader).every_n_steps(config.validation_every_n_steps),
        LoggingCallback().every_n_steps(config.logging_every_n_steps),
    ],
).fit(num_epochs=config.num_epochs)
# Out:
# /home/matveevar/seminar/neuralrec/neuralrec/nn/transformer.py:33: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer_encoder = nn.TransformerEncoder(
# 2026-02-24 12:23:40.783 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=0 loss=13.9110
# 2026-02-24 12:23:42.451 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=0 loss=13.7927 validation/loss=13.7982368850708
# 2026-02-24 12:23:43.300 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=0 loss=13.6811
# 2026-02-24 12:23:44.922 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=0 loss=13.3451 validation/loss=13.322362365722656
# 2026-02-24 12:23:45.780 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=0 loss=12.6244
# 2026-02-24 12:23:47.417 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=0 loss=12.2915 validation/loss=12.631474609375
# 2026-02-24 12:23:48.268 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=0 loss=12.5728
# 2026-02-24 12:23:49.903 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=0 loss=13.0042 validation/loss=12.413756675720215
# 2026-02-24 12:23:50.751 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=0 loss=13.0056
# 2026-02-24 12:23:52.380 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=0 loss=11.9575 validation/loss=12.25926326751709
# 2026-02-24 12:23:53.237 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=0 loss=12.2942
# 2026-02-24 12:23:54.874 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=0 loss=12.1099 validation/loss=12.17060863494873
# 2026-02-24 12:23:55.159 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 0 finished
# 2026-02-24 12:23:56.161 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=1 loss=8.8804
# 2026-02-24 12:23:57.820 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=1 loss=9.2266 validation/loss=12.868744201660157
# 2026-02-24 12:23:58.671 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=1 loss=9.4995
# 2026-02-24 12:24:00.304 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=1 loss=9.4401 validation/loss=12.862016258239747
# 2026-02-24 12:24:01.154 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=1 loss=9.5443
# 2026-02-24 12:24:02.806 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=1 loss=9.7916 validation/loss=12.570456161499024
# 2026-02-24 12:24:03.669 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=1 loss=10.2151
# 2026-02-24 12:24:05.314 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=1 loss=10.7368 validation/loss=12.573883781433105
# 2026-02-24 12:24:06.170 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=1 loss=10.9746
# 2026-02-24 12:24:07.876 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=1 loss=10.3868 validation/loss=12.340823936462403
# 2026-02-24 12:24:08.737 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=1 loss=10.6307
# 2026-02-24 12:24:10.374 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=1 loss=10.6415 validation/loss=12.275249786376953
# 2026-02-24 12:24:10.666 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 1 finished

# %% [markdown]
# # Distributed Data Parallel

# %%
# %%writefile train_ddp.py
from dataclasses import dataclass

import torch
import torch.nn as nn
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data.distributed import DistributedSampler

from neuralrec.nn.transformer import TransformerEncoder
from neuralrec.data.dataloader import DataLoader
from neuralrec.data.transforms import ToDevice
from neuralrec.ext.yambda.utils import load_yambda_user_split
from neuralrec.ext.yambda.transforms import pad_collate_item_id
from neuralrec.run.train import TrainRunner
from neuralrec.run.callbacks import (
    GradientNormClippingCallback,
    LoggingCallback,
    ValidationCallback,
    TensorBoardCallback,
)
from neuralrec.nn.autocast import AutoCast
from neuralrec.run.distributed import (
    init_process_group,
    destroy_process_group,
    is_chief,
)


@dataclass
class PipelineConfig:
    batch_size: int = 1
    d_model: int = 64
    n_heads: int = 4
    dim_feedforward: int = 256
    dropout: float = 0.1
    num_layers: int = 2
    num_epochs: int = 1
    gradient_clipping: float = 1.0
    logging_every_n_steps: int = 10
    validation_every_n_steps: int = 20
    tensorboard_every_n_steps: int = 10
    learning_rate: float = 1e-3


class RecommenderTransformer(nn.Module):
    def __init__(
        self,
        num_items: int,
        d_model: int,
        encoder: nn.Module,
    ):
        super().__init__()
        self.num_items = num_items
        self.embedding = nn.Embedding(num_items + 1, d_model, padding_idx=0)
        self.encoder = encoder
        self.to_logits = nn.Linear(d_model, num_items + 1)

    def forward(self, batch) -> dict[str, torch.Tensor]:
        item_id = batch['item_id']
        x = self.embedding(item_id)
        h = self.encoder(x)
        logits = self.to_logits(h)

        logits_pred = logits[:, :-1].contiguous().view(-1, self.num_items + 1)
        target = item_id[:, 1:].contiguous().view(-1)

        loss = nn.functional.cross_entropy(
            logits_pred, target, ignore_index=0, reduction="mean"
        )
        return {"loss": loss}


def main():
    init_process_group()

    config = PipelineConfig()
    train_dataset, valid_dataset, max_item_id = load_yambda_user_split()

    train_loader = DataLoader(
        dataset=train_dataset,
        batch_size=config.batch_size,
        shuffle=False,
        collate_fn=pad_collate_item_id,
        sampler=DistributedSampler(train_dataset),
        transforms=ToDevice(torch.device("cuda"))
    )
    valid_loader = DataLoader(
        dataset=valid_dataset,
        batch_size=config.batch_size,
        shuffle=False,
        collate_fn=pad_collate_item_id,
        sampler=DistributedSampler(valid_dataset),
        transforms=ToDevice(torch.device("cuda")),
    )

    model = RecommenderTransformer(
        num_items=max_item_id,
        d_model=config.d_model,
        encoder=TransformerEncoder(
            d_model=config.d_model,
            nhead=config.n_heads,
            num_layers=config.num_layers,
            dim_feedforward=config.dim_feedforward,
            dropout=config.dropout,
            causal=True,
        )
    ).cuda()
    model = AutoCast(model)
    model = DDP(model)

    optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate, fused=True)

    TrainRunner(
        model=model,
        optimizer=optimizer,
        train_loader=train_loader,
        callbacks=[
            GradientNormClippingCallback(config.gradient_clipping),
            ValidationCallback(valid_loader).every_n_steps(config.validation_every_n_steps).ignore_if(not is_chief()),
            LoggingCallback().every_n_steps(config.logging_every_n_steps).ignore_if(not is_chief()),
        ],
    ).fit(config.num_epochs)

    destroy_process_group()

if __name__ == "__main__":
    main()
# Out:
# Overwriting train_ddp.py

# %%
# !OMP_NUM_THREADS=1 CUDA_VISIBLE_DEVICES="6,7" torchrun --nproc_per_node 2 train_ddp.py
# Out:
# /home/matveevar/seminar/neuralrec/neuralrec/nn/transformer.py:33: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer_encoder = nn.TransformerEncoder(
# /home/matveevar/seminar/neuralrec/neuralrec/nn/transformer.py:33: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   self.transformer_encoder = nn.TransformerEncoder(
# 2026-02-24 12:25:16.537 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=0 loss=13.7815
# 2026-02-24 12:25:21.896 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=0 loss=13.7387 validation/loss=13.821580657958984
# 2026-02-24 12:25:25.832 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=0 loss=13.6220
# 2026-02-24 12:25:30.368 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=0 loss=13.7461 validation/loss=13.529617347717284
# 2026-02-24 12:25:34.759 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=0 loss=13.0212
# 2026-02-24 12:25:39.896 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=0 loss=13.4631 validation/loss=12.910361423492432
# 2026-02-24 12:25:44.215 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=0 loss=12.6280
# 2026-02-24 12:25:49.438 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=0 loss=12.8839 validation/loss=12.69884494781494
# 2026-02-24 12:25:53.057 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=0 loss=12.2092
# 2026-02-24 12:25:57.508 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=0 loss=12.0994 validation/loss=12.579159889221192
# 2026-02-24 12:26:01.141 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=0 loss=12.7365
# 2026-02-24 12:26:06.302 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=0 loss=12.0849 validation/loss=12.510200672149658
# 2026-02-24 12:26:09.708 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=130 epoch=0 loss=12.2188
# 2026-02-24 12:26:14.613 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=140 epoch=0 loss=12.1319 validation/loss=12.396620101928711
# 2026-02-24 12:26:18.194 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=150 epoch=0 loss=14.3711
# 2026-02-24 12:26:22.817 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=160 epoch=0 loss=11.7970 validation/loss=12.335618934631349
# 2026-02-24 12:26:26.071 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=170 epoch=0 loss=10.0485
# 2026-02-24 12:26:29.979 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=180 epoch=0 loss=10.2867 validation/loss=12.286099834442139
# 2026-02-24 12:26:33.314 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=190 epoch=0 loss=14.0842
# 2026-02-24 12:26:36.731 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=200 epoch=0 loss=12.4112 validation/loss=12.245993633270263
# 2026-02-24 12:26:39.388 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=210 epoch=0 loss=10.6129
# 2026-02-24 12:26:43.129 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=220 epoch=0 loss=14.2687 validation/loss=12.180364360809326
# 2026-02-24 12:26:46.280 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=230 epoch=0 loss=10.7480
# 2026-02-24 12:26:50.172 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=240 epoch=0 loss=13.3278 validation/loss=12.174119472503662
# 2026-02-24 12:26:52.340 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 0 finished
# /home/matveevar/seminar/.conda/lib/python3.10/site-packages/torch/distributed/c10d_logger.py:83: UserWarning: barrier(): using the device under current context. You can specify `device_id` in `init_process_group` to mute this warning.
#   return func(*args, **kwargs)

# %% [markdown]
# # FlashAttention

# %%
from neuralrec.nn.flashattn_transformer import TransformerEncoder as FlashTransformerEncoder


model = RecommenderTransformer(
    num_items=max_item_id,
    d_model=config.d_model,
    encoder=FlashTransformerEncoder(
        d_model=config.d_model,
        nhead=config.n_heads,
        num_layers=config.num_layers,
        dim_feedforward=config.dim_feedforward,
        dropout=config.dropout,
        causal=True,
    )
).cuda()
model = AutoCast(model)  # if using fp16, use GradScaler

optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate, fused=True)

TrainRunner(
    model=model,
    optimizer=optimizer,
    train_loader=train_loader,
    callbacks=[
        GradientNormClippingCallback(config.gradient_clipping),
        ValidationCallback(valid_loader).every_n_steps(config.validation_every_n_steps),
        LoggingCallback().every_n_steps(config.logging_every_n_steps),
    ],
).fit(num_epochs=config.num_epochs)
# Out:
# 2026-02-24 12:27:53.866 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=0 loss=13.7397
# 2026-02-24 12:27:55.485 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=0 loss=13.7815 validation/loss=13.785020523071289
# 2026-02-24 12:27:56.334 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=0 loss=13.6933
# 2026-02-24 12:27:57.941 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=0 loss=13.3355 validation/loss=13.291863975524903
# 2026-02-24 12:27:58.793 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=0 loss=12.4394
# 2026-02-24 12:28:00.455 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=0 loss=12.2967 validation/loss=12.639409141540527
# 2026-02-24 12:28:01.307 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=0 loss=12.5977
# 2026-02-24 12:28:02.916 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=0 loss=13.0365 validation/loss=12.415032539367676
# 2026-02-24 12:28:03.759 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=0 loss=12.9525
# 2026-02-24 12:28:05.380 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=0 loss=11.8777 validation/loss=12.256357078552247
# 2026-02-24 12:28:06.230 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=0 loss=12.2477
# 2026-02-24 12:28:07.859 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=0 loss=12.1376 validation/loss=12.162625503540038
# 2026-02-24 12:28:08.140 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 0 finished
# 2026-02-24 12:28:09.130 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=1 loss=8.7087
# 2026-02-24 12:28:10.796 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=1 loss=9.2597 validation/loss=12.831919593811035
# 2026-02-24 12:28:11.647 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=1 loss=9.5154
# 2026-02-24 12:28:13.257 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=1 loss=9.5280 validation/loss=12.866711158752441
# 2026-02-24 12:28:14.104 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=1 loss=9.5436
# 2026-02-24 12:28:15.726 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=1 loss=9.7627 validation/loss=12.545883140563966
# 2026-02-24 12:28:16.575 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=1 loss=10.0969
# 2026-02-24 12:28:18.191 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=1 loss=10.6104 validation/loss=12.617053298950195
# 2026-02-24 12:28:19.036 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=1 loss=10.8072
# 2026-02-24 12:28:20.686 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=1 loss=10.1287 validation/loss=12.461566352844239
# 2026-02-24 12:28:21.536 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=1 loss=10.5671
# 2026-02-24 12:28:23.194 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=1 loss=10.6519 validation/loss=12.306338577270507
# 2026-02-24 12:28:23.485 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 1 finished

# %% [markdown]
# # Torch Compile

# %%
model = RecommenderTransformer(
    num_items=max_item_id,
    d_model=config.d_model,
    encoder=FlashTransformerEncoder(
        d_model=config.d_model,
        nhead=config.n_heads,
        num_layers=config.num_layers,
        dim_feedforward=config.dim_feedforward,
        dropout=config.dropout,
        causal=True,
    )
).cuda()
model = AutoCast(model)  # if using fp16, use GradScaler
model = torch.compile(model)

optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate, fused=True)

TrainRunner(
    model=model,
    optimizer=optimizer,
    train_loader=train_loader,
    callbacks=[
        GradientNormClippingCallback(config.gradient_clipping),
        ValidationCallback(valid_loader).every_n_steps(config.validation_every_n_steps),
        LoggingCallback().every_n_steps(config.logging_every_n_steps),
    ],
).fit(num_epochs=config.num_epochs)
# Out:
# 2026-02-24 12:28:46.597 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=0 loss=13.7600
# 2026-02-24 12:28:47.951 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=0 loss=13.7926 validation/loss=13.778024978637696
# 2026-02-24 12:28:50.993 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=0 loss=13.6995
# 2026-02-24 12:28:51.851 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=0 loss=13.1980 validation/loss=13.247539176940919
# 2026-02-24 12:28:52.430 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=0 loss=12.5191
# 2026-02-24 12:28:53.284 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=0 loss=12.2631 validation/loss=12.620790328979492
# 2026-02-24 12:28:53.872 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=0 loss=12.6428
# 2026-02-24 12:28:54.735 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=0 loss=12.9806 validation/loss=12.433736038208007
# 2026-02-24 12:28:55.314 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=0 loss=13.0159
# 2026-02-24 12:28:56.221 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=0 loss=12.0133 validation/loss=12.263155555725097
# 2026-02-24 12:28:56.796 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=0 loss=12.3233
# 2026-02-24 12:28:57.677 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=0 loss=12.0970 validation/loss=12.174470100402832
# 2026-02-24 12:28:57.880 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 0 finished
# 2026-02-24 12:28:58.545 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=1 loss=8.6556
# 2026-02-24 12:28:59.411 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=1 loss=9.2470 validation/loss=12.81365306854248
# 2026-02-24 12:28:59.988 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=1 loss=9.5161
# 2026-02-24 12:29:00.871 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=1 loss=9.4733 validation/loss=12.878195343017579
# 2026-02-24 12:29:01.452 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=1 loss=9.5424
# 2026-02-24 12:29:02.305 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=1 loss=9.7782 validation/loss=12.541748237609863
# 2026-02-24 12:29:02.889 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=1 loss=10.2520
# 2026-02-24 12:29:03.793 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=1 loss=10.7151 validation/loss=12.614998092651367
# 2026-02-24 12:29:04.383 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=1 loss=10.9233
# 2026-02-24 12:29:05.248 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=1 loss=10.3389 validation/loss=12.420614738464355
# 2026-02-24 12:29:05.835 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=1 loss=10.5809
# 2026-02-24 12:29:06.695 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=1 loss=10.5218 validation/loss=12.373287811279297
# 2026-02-24 12:29:06.896 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 1 finished

# %% [markdown]
# # Reader

# %%
train_loader = DataLoader(
    dataset=train_dataset,
    batch_size=config.batch_size,
    shuffle=False,
    num_workers=8,  # increase number of workers
    pin_memory=True,  # transfer tensors in pinned memory
    collate_fn=pad_collate_item_id,
    transforms=ToDevice(torch.device("cuda"))
)

model = RecommenderTransformer(
    num_items=max_item_id,
    d_model=config.d_model,
    encoder=FlashTransformerEncoder(
        d_model=config.d_model,
        nhead=config.n_heads,
        num_layers=config.num_layers,
        dim_feedforward=config.dim_feedforward,
        dropout=config.dropout,
        causal=True,
    )
).cuda()
model = AutoCast(model)  # if using fp16, use GradScaler

optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate, fused=True)

TrainRunner(
    model=model,
    optimizer=optimizer,
    train_loader=train_loader,
    callbacks=[
        GradientNormClippingCallback(config.gradient_clipping),
        LoggingCallback().every_n_steps(config.logging_every_n_steps),
    ],
).fit(num_epochs=config.num_epochs)
# Out:
# 2026-02-24 12:29:17.420 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=0 loss=13.8897
# 2026-02-24 12:29:18.285 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=0 loss=13.7382
# 2026-02-24 12:29:19.139 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=0 loss=13.6595
# 2026-02-24 12:29:19.986 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=0 loss=13.1545
# 2026-02-24 12:29:20.840 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=0 loss=12.4328
# 2026-02-24 12:29:21.699 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=0 loss=12.2541
# 2026-02-24 12:29:22.553 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=0 loss=12.7307
# 2026-02-24 12:29:23.416 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=0 loss=13.0257
# 2026-02-24 12:29:24.271 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=0 loss=12.9511
# 2026-02-24 12:29:25.129 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=0 loss=11.9146
# 2026-02-24 12:29:25.985 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=0 loss=12.2824
# 2026-02-24 12:29:26.846 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=0 loss=12.1102
# 2026-02-24 12:29:27.324 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 0 finished
# 2026-02-24 12:29:29.206 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=1 loss=8.8270
# 2026-02-24 12:29:30.066 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=1 loss=9.2061
# 2026-02-24 12:29:30.938 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=1 loss=9.5337
# 2026-02-24 12:29:31.797 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=1 loss=9.5389
# 2026-02-24 12:29:32.655 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=1 loss=9.5800
# 2026-02-24 12:29:33.508 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=1 loss=9.8322
# 2026-02-24 12:29:34.369 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=1 loss=10.2781
# 2026-02-24 12:29:35.236 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=1 loss=10.7942
# 2026-02-24 12:29:36.089 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=1 loss=10.8692
# 2026-02-24 12:29:36.942 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=1 loss=10.2604
# 2026-02-24 12:29:37.798 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=1 loss=10.6717
# 2026-02-24 12:29:38.651 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=1 loss=10.6954
# 2026-02-24 12:29:39.156 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 1 finished

# %%
from neuralrec.data.dataloader import PrefetchDataLoader


train_loader = PrefetchDataLoader(
    dataset=train_dataset,
    batch_size=config.batch_size,
    shuffle=False,
    num_workers=8,  # increase number of workers
    pin_memory=True,  # transfer tensors in pinned memory
    collate_fn=pad_collate_item_id,
    device=torch.device("cuda"),  # move tensors to GPU
    buffer_size=4,  # prefetch 4 batches
)

model = RecommenderTransformer(
    num_items=max_item_id,
    d_model=config.d_model,
    encoder=FlashTransformerEncoder(
        d_model=config.d_model,
        nhead=config.n_heads,
        num_layers=config.num_layers,
        dim_feedforward=config.dim_feedforward,
        dropout=config.dropout,
        causal=True,
    )
).cuda()
model = AutoCast(model)  # if using fp16, use GradScaler

optimizer = torch.optim.AdamW(model.parameters(), lr=config.learning_rate, fused=True)

TrainRunner(
    model=model,
    optimizer=optimizer,
    train_loader=train_loader,
    callbacks=[
        GradientNormClippingCallback(config.gradient_clipping),
        LoggingCallback().every_n_steps(config.logging_every_n_steps),
    ],
).fit(num_epochs=config.num_epochs)
# Out:
# 2026-02-24 12:31:18.824 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=0 loss=13.4475
# 2026-02-24 12:31:19.641 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=0 loss=13.5709
# 2026-02-24 12:31:20.458 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=0 loss=13.2050
# 2026-02-24 12:31:21.272 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=0 loss=12.3948
# 2026-02-24 12:31:22.085 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=0 loss=11.9986
# 2026-02-24 12:31:22.900 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=0 loss=11.9042
# 2026-02-24 12:31:23.717 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=0 loss=12.1935
# 2026-02-24 12:31:24.535 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=0 loss=12.5968
# 2026-02-24 12:31:25.350 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=0 loss=12.7301
# 2026-02-24 12:31:26.165 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=0 loss=11.9359
# 2026-02-24 12:31:26.981 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=0 loss=11.9803
# 2026-02-24 12:31:27.799 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=0 loss=12.0159
# 2026-02-24 12:31:28.103 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 0 finished
# 2026-02-24 12:31:30.042 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=10 epoch=1 loss=7.7738
# 2026-02-24 12:31:30.861 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=20 epoch=1 loss=8.6453
# 2026-02-24 12:31:31.679 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=30 epoch=1 loss=8.5859
# 2026-02-24 12:31:32.498 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=40 epoch=1 loss=8.8419
# 2026-02-24 12:31:33.317 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=50 epoch=1 loss=8.8846
# 2026-02-24 12:31:34.137 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=60 epoch=1 loss=9.1989
# 2026-02-24 12:31:34.957 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=70 epoch=1 loss=9.2855
# 2026-02-24 12:31:35.777 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=80 epoch=1 loss=9.6953
# 2026-02-24 12:31:36.598 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=90 epoch=1 loss=9.7737
# 2026-02-24 12:31:37.418 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=100 epoch=1 loss=9.3955
# 2026-02-24 12:31:38.238 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=110 epoch=1 loss=9.6429
# 2026-02-24 12:31:39.056 | INFO     | neuralrec.run.callbacks.logging:on_step_end:33 - step=120 epoch=1 loss=9.7776
# 2026-02-24 12:31:39.259 | INFO     | neuralrec.run.callbacks.logging:on_epoch_end:36 - epoch 1 finished

# %% [markdown]
# # What is missing
# 1. Snapshotting (saving checkpoints)
# 2. Metric reduction in distributed training
# 3. Gradient Checkpointing
# 4. Ensure parameters have an optimizer
# 5. Ensure parameters have gradients
# 6. Ensure parameters don't have duplicated optimizer groups
# 7. Gradient accumulation
# 8. ...
